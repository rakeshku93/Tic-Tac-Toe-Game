# %%
old_board = [[0,0,0] , [0,0,0] , [0,0,0]]
input_list = []

def getBlocks(boards):
    for i in boards:
        for j in i:
            print(j, end = "  ")
        print()
        
# Ask the user whether he/she wants to continue the game or not?      
def regame():
    regame = int(input('''Wants to play again
    If 'Yes' press 1 or for 'No' press 2  '''))
    if regame == 1:
        new_board = [[0,0,0] , [0,0,0] , [0,0,0]]
        vin = new_board
        input_list.clear()
        askuser(vin)
    else:
        print('Thanks for playing the game!!!')

# Case 1:  Player 1 chooses 'X'

def player1x (board):
        p11,p12 = input('Player 1 : Enter your position on the board ').split()
        if (int(p11),int(p12)) in input_list:
            print('Position already covered,Enter new position')
            player1x (board)
        else:
            input_list.append((int(p11),int(p12)))
            if int(p11)<3 and int(p12)<3 :
                board[int(p11)][int(p12)] = 'X'
                print('-------')
                getBlocks(board)
                print('-------')

            else:
                print('Enter the correct position')
                player1x(board)
            
def player2o(board):
        p11,p12 = input('Player 2 \'s turn ,Player 2 enter your position on the board ').split()
        if (int(p11),int(p12)) in input_list:
            print('Position already covered,Enter new position')
            player2o(board)
        else:
            input_list.append((int(p11),int(p12)))
            if int(p11)<3 and int(p12)<3:
                board[int(p11)][int(p12)] = 'O'
                print('-------')
                getBlocks(board)
                print('-------') 
            else:
                print('Enter the correct position')
                player2o(board)
                
# Case 2:  Player 1 chooses 'O' 

def player1o ():
        print('Player 1 : Enter your position on the board')
        p11,p12 = input().split()
        if (int(p11),int(p12)) in input_list:
            print('Position already covered,Enter new position')
            player2o(board)
        else:
            input_list.append((int(p11),int(p12)))
            
            if int(p11)<3 and int(p12)<3:
                board[int(p11)][int(p12)] = 'O'
                print('-------')
                getBlocks()
                print('-------')
            else:
                print('Enter the correct position')
                player1o(board)
def player2x(): 
        print('Player 2 \'s turn ,Player 2 enter your position on the board')
        p11,p12 = input().split()
        if (int(p11),int(p12)) in input_list:
            print('Position already covered,Enter new position')
            player2o(board)
        else:
            input_list.append((int(p11),int(p12)))
            
            if int(p11)<3 and int(p12)<3:
                board[int(p11)][int(p12)] = 'X'
                print('-------')
                getBlocks()
                print('-------') 
            else:
                print('Enter the correct position')
                player2x(board)

##****************** Games Begins Here ******************************************
def askuser (board):
    # Asking for the choice of the player 1 
    marker = input('Player 1 select your marker b/w X or O & you\'ve selected ').upper()
    while not (marker == 'X' or marker == 'O'): # if user enters wrong input while loop comes into action
        print('You\'ve selected wrong marker,Please select the correct marker')
        marker = input('Player 1: Do you want to be X or O? ').upper()

    if marker == 'X':        
        print('Player 1 has selected marker as',marker)
        print('So,now Marker of Player 2 is O')
        print('The board is empty now, Have a look')
        print('-------')
        getBlocks(board)
        print('-------')
        
        # Player 1 : 1st turn
        player1x(board)
        
        # player 2 : 1st turn
        player2o(board)
        
        # Player 1 : 2nd turn
        player1x(board)
        
        # player 2 : 2nd turn
        player2o(board)
        
        # Player 1 : 3rd turn
        player1x(board)
        
        if board[0][0]==board[0][1]==board[0][2] or board[1][0]==board[1][1]==board[1][2] or board[2][0]==board[2][1]==board[2][2] or board[0][0]==board[1][0]==board[2][0] or board[0][1]== board[1][1]==board[2][1] or board[0][2]==board[1][2]==board[2][2] or board[0][0]==board[1][1]==board[2][2] or board[0][2]==board[1][1]==board[2][0]:
            print('Player 1 wins')
            regame()
            
        else:
            # player 2 : 3rd turn
            player2o(board)
            
            if board[0][0]==board[0][1]==board[0][2] or board[1][0]==board[1][1]==board[1][2] or board[2][0]==board[2][1]==board[2][2] or board[0][0]==board[1][0]==board[2][0] or board[0][1]== board[1][1]==board[2][1] or board[0][2]==board[1][2]==board[2][2] or board[0][0]==board[1][1]==board[2][2] or board[0][2]==board[1][1]==board[2][0]:
                print('Player 2 wins')
                regame()
            
            else:
                # Player 1 : 4th turn
                player1x(board)
                
                if board[0][0]==board[0][1]==board[0][2] or board[1][0]==board[1][1]==board[1][2] or board[2][0]==board[2][1]==board[2][2] or board[0][0]==board[1][0]==board[2][0] or board[0][1]== board[1][1]==board[2][1] or board[0][2]==board[1][2]==board[2][2] or board[0][0]==board[1][1]==board[2][2] or board[0][2]==board[1][1]==board[2][0]:
                    print('Player 1 wins')
                    regame()
                    
                else:
                    # player 2 : 4th turn
                    player2o(board)
                    
                    if board[0][0]==board[0][1]==board[0][2] or board[1][0]==board[1][1]==board[1][2] or board[2][0]==board[2][1]==board[2][2] or board[0][0]==board[1][0]==board[2][0] or board[0][1]== board[1][1]==board[2][1] or board[0][2]==board[1][2]==board[2][2] or board[0][0]==board[1][1]==board[2][2] or board[0][2]==board[1][1]==board[2][0]:
                        print('Player 2 wins')
                        regame()
                    
                    else:
                        # Player 1 : last turn
                        player1x(board)
                        
                        if board[0][0]==board[0][1]==board[0][2] or board[1][0]==board[1][1]==board[1][2] or board[2][0]==board[2][1]==board[2][2] or board[0][0]==board[1][0]==board[2][0] or board[0][1]== board[1][1]==board[2][1] or board[0][2]==board[1][2]==board[2][2] or board[0][0]==board[1][1]==board[2][2] or board[0][2]==board[1][1]==board[2][0]:
                            print('Player 1 wins')
                            regame()
                        
                        else:
                            print('It\'s a tie !!',end = "")
                            regame()
        
    elif marker != 'X':
        
        print('Player 1 has selected marker as',marker)
        print('So,now Marker of Player 2 is X')
        print('The board is empty now, Have a look')
        print('-------')
        getBlocks(board)
        print('-------')
        
        # Player 1 : 1st turn
        player1o(board)
        
        # player 2 : 1st turn
        player2x(board)
        
        # Player 1 : 2nd turn
        player1o(board)
        
        # player 2 : 2nd turn
        player2x(board)
        
        
        # Player 1 : 3rd turn
        player1o (board)
        
        if board[0][0]==board[0][1]==board[0][2] or board[1][0]==board[1][1]==board[1][2] or board[2][0]==board[2][1]==board[2][2] or board[0][0]==board[1][0]==board[2][0] or board[0][1]== board[1][1]==board[2][1] or board[0][2]==board[1][2]==board[2][2] or board[0][0]==board[1][1]==board[2][2] or board[0][2]==board[1][1]==board[2][0]:
            print('Player 1 wins')
            regame()
            
        else:
             # player 2 : 3rd turn
            player2x (board)
            
            if board[0][0]==board[0][1]==board[0][2] or board[1][0]==board[1][1]==board[1][2] or board[2][0]==board[2][1]==board[2][2]or board[0][0]==board[1][0]==board[2][0] or board[0][1]== board[1][1]==board[2][1] or board[0][2]==board[1][2]==board[2][2] or board[0][0]==board[1][1]==board[22] or board[0][2]==board[1][1]==board[2][0]:
                print('Player 2 wins')
                regame()
            
            else:
                # Player 1 : 4th turn
                player1o (board)
                
                if board[0][0]==board[0][1]==board[0][2] or board[1][0]==board[1][1]==board[1][2] or board[2][0]==board[2][1]==board[2][2] or board[0][0]==board[1][0]==board[2][0] or board[0][1]== board[1][1]==board[2][1] or board[0][2]==board[1][2]==board[2][2] or board[0][0]==board[1][1]==board[2][2] or board[0][2]==board[1][1]==board[2][0]:
                    print('Player 1 wins')
                    regame()
                    
                else:
                     # player 2 : 4th turn
                    player2x (board)
                    
                    if board[0][0]==board[0][1]==board[0][2] or board[1][0]==board[1][1]==board[1][2] or board[2][0]==board[2][1]==board[2][2] or board[0][0]==board[1][0]==board[2][0] or board[0][1]== board[1][1]==board[2][1] or board[0][2]==board[1][2]==board[2][2] or board[0][0]==board[1][1]==board[2][2] or board[0][2]==board[1][1]==board[2][0]:
                        print('Player 2 wins')
                        regame()
                    else:
                        # Player 1 : last turn
                        player1o (board)

                        if board[0][0]==board[0][1]==board[0][2] or board[1][0]==board[1][1]==board[1][2] or board[2][0]==board[2][1]==board[2][2] or board[0][0]==board[1][0]==board[2][0] or board[0][1]== board[1][1]==board[2][1] or board[0][2]==board[1][2]==board[2][2] or board[0][0]==board[1][1]==board[2][2] or board[0][2]==board[1][1]==board[2][0]:
                            print('Player 1 wins')
                            regame()
                    
                        else:
                            print('It\'s a tie !!')
                            regame()
                        
askuser(old_board)
# Out:
# Player 1 select your marker b/w X or O & you've selected m
# You've selected wrong marker,Please select the correct marker
# Player 1: Do you want to be X or O? x
# Player 1 has selected marker as X
# So,now Marker of Player 2 is O
# The board is empty now, Have a look
# -------
# 0  0  0
# 0  0  0
# 0  0  0
# -------
# Player 1 : Enter your position on the board 2 3
# Enter the correct position
# Player 1 : Enter your position on the board 2 3
# Position already covered,Enter new position
# Player 1 : Enter your position on the board 2 2
# -------
# 0  0  0
# 0  0  0
# 0  0  X
# -------
# Player 2 's turn ,Player 2 enter your position on the board 2 0
# -------
# 0  0  0
# 0  0  0
# O  0  X
# -------
# Player 1 : Enter your position on the board 0 1
# -------
# 0  X  0
# 0  0  0
# O  0  X
# -------
# Player 2 's turn ,Player 2 enter your position on the board 1 1
# -------
# 0  X  0
# 0  O  0
# O  0  X
# -------
# Player 1 : Enter your position on the board nn
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-411d5e0f60c9> in <module>
#     227                             regame()
#     228
# --> 229 askuser(old_board)
#     230
#
# <ipython-input-1-411d5e0f60c9> in askuser(board)
#     121
#     122         # Player 1 : 3rd turn
# --> 123         player1x(board)
#     124
#     125         if board[0][0]==board[0][1]==board[0][2] or board[1][0]==board[1][1]==board[1][2] or board[2][0]==board[2][1]==board[2][2] or board[0][0]==board[1][0]==board[2][0] or board[0][1]== board[1][1]==board[2][1] or board[0][2]==board[1][2]==board[2][2] or board[0][0]==board[1][1]==board[2][2] or board[0][2]==board[1][1]==board[2][0]:
#
# <ipython-input-1-411d5e0f60c9> in player1x(board)
#      23
#      24 def player1x (board):
# ---> 25         p11,p12 = input('Player 1 : Enter your position on the board ').split()
#      26         if (int(p11),int(p12)) in input_list:
#      27             print('Position already covered,Enter new position')
#
# ValueError: not enough values to unpack (expected 2, got 1)
